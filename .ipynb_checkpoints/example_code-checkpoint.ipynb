# %%
import os
os.environ['USE_PYGEOS'] = '0'
import re
import json
import math
import h5py
import shutil
import zipfile
import requests
import datetime
import numpy as np
import pandas as pd
import geopandas as gpd
from shapely.geometry.polygon import orient
from shapely.geometry import Polygon, mapping
from xml.etree import ElementTree as ET

# %%
def make_granule_list(geojson, short_name='ATL03',
                      start_date='2018-01-01', end_date='2030-01-01', 
                      start_time='00:00:00', end_time='23:59:59',
                      simplify_geometry=False,
                      write_csv=False, return_df=True,
                      list_out_name=None, 
                      geojson_dir='geojsons/'):

    temporal = start_date + 'T' + start_time + 'Z' + ',' + end_date + 'T' + end_time + 'Z'
    cmr_collections_url = 'https://cmr.earthdata.nasa.gov/search/collections.json'
    granule_search_url = 'https://cmr.earthdata.nasa.gov/search/granules'
    base_url = 'https://n5eil02u.ecs.nsidc.org/egi/request'

    # Get json response from CMR collection metadata
    params = {'short_name': short_name}
    response = requests.get(cmr_collections_url, params=params)
    results = json.loads(response.content)

    # Find all instances of 'version_id' in metadata and print most recent version number
    versions = [el['version_id'] for el in results['feed']['entry']]
    latest_version = max(versions)
    capability_url = f'https://n5eil02u.ecs.nsidc.org/egi/capabilities/{short_name}.{latest_version}.xml'

    # read in geojson file
    gdf = gpd.read_file(geojson_dir + geojson)
    if simplify_geometry:
        print('Simplifying input region...')
        gdf = gdf.simplify(0.05, preserve_topology=True)
        
    gdf['geometry'] = orient(gdf.geometry.loc[0],sign=1.0)
    polygon = ','.join([str(c) for xy in zip(*gdf.exterior.loc[0].coords.xy) for c in xy])
    search_params = {'short_name': short_name, 'version': latest_version, 'temporal': temporal, 'page_size': 100,
                     'page_num': 1,'polygon': polygon}

    # query for granules 
    granules = []
    headers={'Accept': 'application/json'}
    while True:
        response = requests.get(granule_search_url, params=search_params, headers=headers)
        results = json.loads(response.content)

        if len(results['feed']['entry']) == 0:
            break # Out of results, so break out of loop

        # Collect results and increment page_num
        granules.extend(results['feed']['entry'])
        search_params['page_num'] += 1

    granule_list, idx_unique = np.unique(np.array([g['producer_granule_id'] for g in granules]), return_index=True)
    granules = [g for i,g in enumerate(granules) if i in idx_unique]
    size_mb = [float(result["granule_size"]) for result in granules]
    
    print('Found %i %s version %s granules over %s between %s and %s.' % (len(granule_list), short_name, latest_version, 
                                                                          geojson, start_date, end_date))

    thisdf = pd.DataFrame({'granule': granule_list, 
                           'region': geojson, 
                           'size_mb': size_mb})
    
    print('The total size of all granules is %s GB.' % f'{np.round(thisdf.size_mb.sum()/1024,2):,}')

    if write_csv:
        if not list_out_name:
            list_out_name = 'granule_lists/%s_%s_%s_%s.csv' % (geojson.replace('.geojson', ''), 
                                                               short_name, start_date, end_date)
        thisdf.to_csv(list_out_name, index=False)
        print('Wrote file: %s' % list_out_name)
        
    if return_df:
        return thisdf

# %%
make_granule_list('simplified_ANT_1000_East_B-C.geojson', start_date='2021-01-01', end_date='2021-03-01', 
                  simplify_geometry=False, write_csv=True)
# Out:
# Found 54 ATL03 version 006 granules over simplified_ANT_1000_East_B-C.geojson between 2021-01-01 and 2021-03-01.
# The total size of all granules is 138.56 GB.
# Wrote file: granule_lists/simplified_ANT_1000_East_B-C_ATL03_2021-01-01_2021-03-01.csv
# 3   simplified_ANT_1000_East_B-C.geojson  1434.215286
# 4   simplified_ANT_1000_East_B-C.geojson  5749.245593
# 5   simplified_ANT_1000_East_B-C.geojson  1493.665640
# 6   simplified_ANT_1000_East_B-C.geojson  6011.741141
# 7   simplified_ANT_1000_East_B-C.geojson  1536.959898
# 8   simplified_ANT_1000_East_B-C.geojson  4792.984506
# 9   simplified_ANT_1000_East_B-C.geojson  1546.871660
# 10  simplified_ANT_1000_East_B-C.geojson  5704.176262
# 11  simplified_ANT_1000_East_B-C.geojson  1319.138063
# 12  simplified_ANT_1000_East_B-C.geojson  1018.700623
# 13  simplified_ANT_1000_East_B-C.geojson  4098.482604
# 14  simplified_ANT_1000_East_B-C.geojson   846.797906
# 15  simplified_ANT_1000_East_B-C.geojson  1340.281366
# 16  simplified_ANT_1000_East_B-C.geojson  4848.114173
# 17  simplified_ANT_1000_East_B-C.geojson  1234.561011
# 18  simplified_ANT_1000_East_B-C.geojson  1079.701638
# 19  simplified_ANT_1000_East_B-C.geojson  5408.375190
# 20  simplified_ANT_1000_East_B-C.geojson   732.271417
# 21  simplified_ANT_1000_East_B-C.geojson   602.202868
# 22  simplified_ANT_1000_East_B-C.geojson  5589.739006
# 23  simplified_ANT_1000_East_B-C.geojson  1272.660385
# 24  simplified_ANT_1000_East_B-C.geojson  4591.979358
# 25  simplified_ANT_1000_East_B-C.geojson   962.049204
# 26  simplified_ANT_1000_East_B-C.geojson  4869.477048
# 27  simplified_ANT_1000_East_B-C.geojson  1200.598209
# 28  simplified_ANT_1000_East_B-C.geojson  4779.580261
# 29  simplified_ANT_1000_East_B-C.geojson   760.046837
# 30  simplified_ANT_1000_East_B-C.geojson  4860.617976
# 31  simplified_ANT_1000_East_B-C.geojson   678.684320
# 32  simplified_ANT_1000_East_B-C.geojson  5219.381323
# 33  simplified_ANT_1000_East_B-C.geojson   655.781507
# 34  simplified_ANT_1000_East_B-C.geojson  4556.916944
# 35  simplified_ANT_1000_East_B-C.geojson  1051.253425
# 36  simplified_ANT_1000_East_B-C.geojson  4175.017743
# 37  simplified_ANT_1000_East_B-C.geojson   996.299724
# 38  simplified_ANT_1000_East_B-C.geojson  3909.213207
# 39  simplified_ANT_1000_East_B-C.geojson   840.768193
# 40  simplified_ANT_1000_East_B-C.geojson  4043.910224
# 41  simplified_ANT_1000_East_B-C.geojson  1063.748739
# 42  simplified_ANT_1000_East_B-C.geojson   695.110035
# 43  simplified_ANT_1000_East_B-C.geojson  4846.767948
# 44  simplified_ANT_1000_East_B-C.geojson  1125.199482
# 45  simplified_ANT_1000_East_B-C.geojson  1033.231171
# 46  simplified_ANT_1000_East_B-C.geojson  3942.346274
# 47  simplified_ANT_1000_East_B-C.geojson   769.689764
# 48  simplified_ANT_1000_East_B-C.geojson   413.614100
# 49  simplified_ANT_1000_East_B-C.geojson  3399.310479
# 50  simplified_ANT_1000_East_B-C.geojson   712.807619
# 51  simplified_ANT_1000_East_B-C.geojson   796.341692
# 52  simplified_ANT_1000_East_B-C.geojson  3600.115624
# 53  simplified_ANT_1000_East_B-C.geojson   470.531092
